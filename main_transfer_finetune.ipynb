# %%
# install pytorch and torchvision
# !pip3 install torchvision==0.2.2
# !pip3 install torch==1.0.0 -f https://download.pytorch.org/whl/cu92/stable
# Out:
# ...
#      |████████████████████████████████| 71kB 4.7MB/s
# ...
#      |████████████████████████████████| 61kB 28.9MB/s
# ...
#   Found existing installation: tqdm 4.28.1
#     Uninstalling tqdm-4.28.1:
#       Successfully uninstalled tqdm-4.28.1
#   Found existing installation: torchvision 0.3.0
#     Uninstalling torchvision-0.3.0:
#       Successfully uninstalled torchvision-0.3.0
# ...
# Looking in links: https://download.pytorch.org/whl/cu92/stable
# ...
#      |████████████████████████████████| 591.8MB 26kB/s
# ...
#   Found existing installation: torch 1.1.0
#     Uninstalling torch-1.1.0:
#       Successfully uninstalled torch-1.1.0
# ...

# %%
# install pydrive to access imagenet stored in googledrive
# !pip install -U -q pydrive
# Out:
#      |████████████████████████████████| 993kB 4.9MB/s
# ...

# %%
# import librarys to access googledrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth, drive
from oauth2client.client import GoogleCredentials

# import pytorch and related packages
import torch
import torchvision
from torchvision import transforms

# import common packages
import os

# %%
# mount googledrive
drive.mount('./Drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at ./Drive

# %%
# update custom packages
if not os.path.exists('/content/dsfinal'):
    # !git clone https://github.com/luk1684tw/dsfinal.git
# %cd /content/dsfinal
# !git pull
os.getcwd()
# Out:
# Cloning into 'dsfinal'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 3797 (delta 16), reused 20 (delta 10), pack-reused 3769
# Receiving objects: 100% (3797/3797), 7.29 MiB | 13.00 MiB/s, done.
# Resolving deltas: 100% (1319/1319), done.
# /content/dsfinal
# Already up to date.
# '/content/dsfinal'

# %%
# %cd l1-norm-pruning/
# !python main_transfer.py --dataset cifar10 --scratch finetuneA100.pth.tar --method 0 --dist A100
# !python main_transfer.py --dataset cifar10 --scratch finetuneA200.pth.tar --method 0 --dist A200
# !python main_transfer.py --dataset cifar10 --scratch finetuneA500.pth.tar --method 0 --dist A500
# Out:
# /content/dsfinal/l1-norm-pruning
# [INFO] Method:  finetune
# [INFO] Start creating datasets
# [INFO] Creating dataloader
# [INFO] Return dataloaders
# [INFO] Loading model from /content/Drive/My Drive/Colab Notebooks/models/finetune/finetuneA500.pth.tar
# Old model features:  10
# [INFO] In Features 1024
# Get the new trasfer learning model vgg(
#   (feature): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
# %cd l1-norm-pruning/
# !python main_transfer.py --dataset cifar10 --scratch modelB100_best.pth.tar --method 0 --dist B100
# !python main_transfer.py --dataset cifar10 --scratch modelB200_best.pth.tar --method 0 --dist B200
# !python main_transfer.py --dataset cifar10 --scratch modelB500_best.pth.tar --method 0 --dist B500
# Out:
# /content/dsfinal/l1-norm-pruning
# [INFO] Method:  finetune
# [INFO] Start creating datasets
# [INFO] Creating dataloader
# [INFO] Return dataloaders
# [INFO] Loading model from /content/Drive/My Drive/Colab Notebooks/models/finetune/modelB500_best.pth.tar
# Old model features:  10
# [INFO] In Features 1024
# Get the new trasfer learning model vgg(
#   (feature): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
# %cd l1-norm-pruning/
# !python main_transfer.py --dataset cifar10 --scratch modelC100_best.pth.tar --method 0 --dist C100
# !python main_transfer.py --dataset cifar10 --scratch modelC200_best.pth.tar --method 0 --dist C200
# !python main_transfer.py --dataset cifar10 --scratch modelC500_best.pth.tar --method 0 --dist C500
# Out:
# /content/dsfinal/l1-norm-pruning
# [INFO] Method:  finetune
# [INFO] Start creating datasets
# [INFO] Creating dataloader
# [INFO] Return dataloaders
# [INFO] Loading model from /content/Drive/My Drive/Colab Notebooks/models/finetune/modelC200_best.pth.tar
# Old model features:  10
# [INFO] In Features 1024
# Get the new trasfer learning model vgg(
#   (feature): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
# %cd l1-norm-pruning/
# !python main_transfer.py --dataset cifar10 --scratch modelA100_best.pth.tar --method 1 --dist A100
# !python main_transfer.py --dataset cifar10 --scratch modelA200_best.pth.tar --method 1 --dist A200
# !python main_transfer.py --dataset cifar10 --scratch modelA500_best.pth.tar --method 1 --dist A500
# Out:
# /content/dsfinal/l1-norm-pruning
# [INFO] Method:  scratchB
# [INFO] Start creating datasets
# [INFO] Creating dataloader
# [INFO] Return dataloaders
# [INFO] Loading model from /content/Drive/My Drive/Colab Notebooks/models/scratchB/modelA500_best.pth.tar
# Old model features:  10
# [INFO] In Features 1024
# Get the new transfer learning model vgg(
#   (feature): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...

# %%
# %cd l1-norm-pruning/
# !python main_transfer.py --dataset cifar10 --scratch modelB100_best.pth.tar --method 1 --dist B100
# !python main_transfer.py --dataset cifar10 --scratch modelB200_best.pth.tar --method 1 --dist B200
# !python main_transfer.py --dataset cifar10 --scratch modelB500_best.pth.tar --method 1 --dist B500
# Out:
# /content/dsfinal/l1-norm-pruning
# [INFO] Method:  scratchB
# [INFO] Start creating datasets
# [INFO] Creating dataloader
# [INFO] Return dataloaders
# [INFO] Loading model from /content/Drive/My Drive/Colab Notebooks/models/scratchB/modelB200_best.pth.tar
# Old model features:  10
# [INFO] In Features 1024
# Get the new transfer learning model vgg(
#   (feature): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...
