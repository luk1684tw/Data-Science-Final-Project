# %%
# install pytorch and torchvision
# !pip3 install torchvision==0.2.2
# !pip3 install torch==1.0.0 -f https://download.pytorch.org/whl/cu92/stable
# Out:
# ...
# Looking in links: https://download.pytorch.org/whl/cu92/stable
# ...

# %%
# install pydrive to access imagenet stored in googledrive
# !pip install -U -q pydrive
# Out:
#      |████████████████████████████████| 993kB 3.4MB/s
# ...

# %%
# import librarys to access googledrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth, drive
from oauth2client.client import GoogleCredentials

# import pytorch and related packages
import torch
import torchvision
from torchvision import transforms

# import common packages
import os

# %%
# mount googledrive
drive.mount('./Drive', force_remount=True)
# Out:
# Mounted at ./Drive

# %%
# update custom packages
if not os.path.exists('/content/dsfinal'):
    # !git clone https://github.com/luk1684tw/dsfinal.git
# %cd /content/dsfinal
# !git pull
os.getcwd()
# Out:
# /content/dsfinal
# Already up to date.
# '/content/dsfinal'

# %%
print (torch.__version__)
# Out:
# 1.0.0

# %%
# %cd l1-norm-pruning/
# !python vggprune.py --dataset cifar10 --model 'baseline/checkpointDistA75.pth.tar' --dist A75
# !python vggprune.py --dataset cifar10 --model 'baseline/checkpointDistB75.pth.tar' --dist B75
# !python vggprune.py --dataset cifar10 --model 'baseline/checkpointDistC75.pth.tar' --dist C75

# %%
# %cd l1-norm-pruning/
# !python vggprune.py --dataset cifar10 --model 'baseline/checkpointDistA100.pth.tar' --dist A100
# !python vggprune.py --dataset cifar10 --model 'baseline/checkpointDistB100.pth.tar' --dist B100
# !python vggprune.py --dataset cifar10 --model 'baseline/checkpointDistC100.pth.tar' --dist C100

# %%
# %cd l1-norm-pruning/
# !python vggprune.py --dataset cifar10 --model 'baseline/checkpointDistA200.pth.tar' --dist A200
# !python vggprune.py --dataset cifar10 --model 'baseline/checkpointDistB200.pth.tar' --dist B200
# !python vggprune.py --dataset cifar10 --model 'baseline/checkpointDistC200.pth.tar' --dist C200
# Out:
# /content/dsfinal/l1-norm-pruning
# /content/Drive/My Drive/Colab Notebooks/models/baseline/checkpointDistA200.pth.tar
# => loading checkpoint '/content/Drive/My Drive/Colab Notebooks/models/baseline/checkpointDistA200.pth.tar'
# => loaded checkpoint '/content/Drive/My Drive/Colab Notebooks/models/baseline/checkpointDistA200.pth.tar' (epoch 120) Prec1: 0.806300
# Pre-processing Successful!
# [INFO] Start creating datasets
# [INFO] Distribution number is 200
# [INFO] Label distribution ratio: [1, 1, 1, 200, 1, 1, 1, 1, 1, 1]
# Files already downloaded and verified
# Files already downloaded and verified
# [INFO] Creating sampler
# [INFO] Creating dataloader
# [INFO] Return dataloaders
# vggprune.py:74: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   data, target = Variable(data, volatile=True), Variable(target)
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=405 error=11 : invalid argument
#
# ...

# %%
# %cd l1-norm-pruning/
# !python vggprune.py --dataset cifar10 --model 'baseline/checkpointDistA500.pth.tar' --dist A500
# !python vggprune.py --dataset cifar10 --model 'baseline/checkpointDistB500.pth.tar' --dist B500
# !python vggprune.py --dataset cifar10 --model 'baseline/checkpointDistC500.pth.tar' --dist C500
# Out:
# /content/dsfinal/l1-norm-pruning
# /content/Drive/My Drive/Colab Notebooks/models/baseline/checkpointDistA500.pth.tar
# => no checkpoint found at '/content/Drive/My Drive/Colab Notebooks/models/baseline/checkpointDistA500.pth.tar'
# Pre-processing Successful!
# [INFO] Start creating datasets
# [INFO] Distribution number is 500
# [INFO] Label distribution ratio: [1, 1, 1, 1, 1, 1, 500, 1, 1, 1]
# Files already downloaded and verified
# Files already downloaded and verified
# [INFO] Creating sampler
# [INFO] Creating dataloader
# [INFO] Return dataloaders
# vggprune.py:74: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   data, target = Variable(data, volatile=True), Variable(target)
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=405 error=11 : invalid argument
# ...
