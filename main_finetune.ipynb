# %%
# install pytorch and torchvision
# !pip3 install torchvision==0.2.2
# !pip3 install torch==1.0.0 -f https://download.pytorch.org/whl/cu92/stable
# Out:
# ...
#      |████████████████████████████████| 71kB 2.8MB/s
# ...
#      |████████████████████████████████| 61kB 22.8MB/s
# ...
#   Found existing installation: tqdm 4.28.1
#     Uninstalling tqdm-4.28.1:
#       Successfully uninstalled tqdm-4.28.1
#   Found existing installation: torchvision 0.3.0
#     Uninstalling torchvision-0.3.0:
#       Successfully uninstalled torchvision-0.3.0
# ...
# Looking in links: https://download.pytorch.org/whl/cu92/stable
# ...
#      |████████████████████████████████| 591.8MB 26kB/s
# ...
#   Found existing installation: torch 1.1.0
#     Uninstalling torch-1.1.0:
#       Successfully uninstalled torch-1.1.0
# ...

# %%
# install pydrive to access imagenet stored in googledrive
# !pip install -U -q pydrive
# Out:
#      |████████████████████████████████| 993kB 2.9MB/s
# ...

# %%
# import librarys to access googledrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth, drive
from oauth2client.client import GoogleCredentials

# import pytorch and related packages
import torch
import torchvision
from torchvision import transforms

# import common packages
import os

# %%
# mount googledrive
drive.mount('./Drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at ./Drive

# %%
# update custom packages
if not os.path.exists('/content/dsfinal'):
    # !git clone https://github.com/luk1684tw/dsfinal.git
# %cd /content/dsfinal
# !git pull
os.getcwd()
# Out:
# Cloning into 'dsfinal'...
# remote: Enumerating objects: 262, done.
# remote: Counting objects: 100% (262/262), done.
# remote: Compressing objects: 100% (164/164), done.
# remote: Total 3759 (delta 187), reused 155 (delta 92), pack-reused 3497
# Receiving objects: 100% (3759/3759), 7.29 MiB | 17.94 MiB/s, done.
# Resolving deltas: 100% (1286/1286), done.
# /content/dsfinal
# Already up to date.
# '/content/dsfinal'

# %%
# %cd l1-norm-pruning/
# !python main_finetune.py --refine prunedA75.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist A75
# !python main_finetune.py --refine prunedB75.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist B75
# !python main_finetune.py --refine prunedC75.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist C75

# %%
# %cd l1-norm-pruning/
# !python main_finetune.py --refine prunedA100.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist A100
# !python main_finetune.py --refine prunedB100.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist B100
# !python main_finetune.py --refine prunedC100.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist C100

# %%
# %cd l1-norm-pruning/
# !python main_finetune.py --refine prunedA200.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist A200
# !python main_finetune.py --refine prunedB200.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist B200
# !python main_finetune.py --refine prunedC200.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist C200

# %%
# %cd l1-norm-pruning/
# !python main_finetune.py --refine prunedA500.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist A500 --epochs 60
# !python main_finetune.py --refine prunedB500.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist B500
# !python main_finetune.py --refine prunedC500.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist C500
# Out:
# /content/dsfinal/l1-norm-pruning
# A500
# [INFO] Start creating datasets
# [INFO] Distribution number is 500
# [INFO] Label distribution ratio: [1, 1, 1, 1, 1, 1, 500, 1, 1, 1]
# Files already downloaded and verified
# Files already downloaded and verified
# [INFO] Creating sampler
# [INFO] Creating dataloader
# [INFO] Return dataloaders
# [INFO] Loading pruned-model from /content/Drive/My Drive/Colab Notebooks/models/pruned/prunedA500.pth.tar
# Train Epoch: 0 [0/50000 (0.0%)]	Loss: 2.396163
# Train Epoch: 0 [6400/50000 (12.8%)]	Loss: 0.117286
# Train Epoch: 0 [12800/50000 (25.6%)]	Loss: 0.270222
# Train Epoch: 0 [19200/50000 (38.4%)]	Loss: 0.083084
# Train Epoch: 0 [25600/50000 (51.2%)]	Loss: 0.225349
# Train Epoch: 0 [32000/50000 (63.9%)]	Loss: 0.113055
# Train Epoch: 0 [38400/50000 (76.7%)]	Loss: 0.097820
# Train Epoch: 0 [44800/50000 (89.5%)]	Loss: 0.165503
# main_finetune.py:130: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# ...
