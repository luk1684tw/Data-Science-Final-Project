# %%
# install pytorch and torchvision
# !pip3 install torchvision==0.2.2
# !pip3 install torch==1.0.0 -f https://download.pytorch.org/whl/cu92/stable
# !pip3 install -U -q pydrive
# Out:
# ...
#      |████████████████████████████████| 71kB 2.7MB/s
# ...
#      |████████████████████████████████| 61kB 22.0MB/s
# ...
#   Found existing installation: tqdm 4.28.1
#     Uninstalling tqdm-4.28.1:
#       Successfully uninstalled tqdm-4.28.1
#   Found existing installation: torchvision 0.3.0
#     Uninstalling torchvision-0.3.0:
#       Successfully uninstalled torchvision-0.3.0
# ...
# Looking in links: https://download.pytorch.org/whl/cu92/stable
# ...
#      |████████████████████████████████| 591.8MB 26kB/s
# ...
#   Found existing installation: torch 1.1.0
#     Uninstalling torch-1.1.0:
#       Successfully uninstalled torch-1.1.0
# ...
#      |████████████████████████████████| 993kB 2.8MB/s
# ...

# %%
# import librarys to access googledrive

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth, drive
from oauth2client.client import GoogleCredentials

# import pytorch and related packages
import torch
import torchvision
from torchvision import transforms

# import common packages
import os

# %%
# mount googledrive
drive.mount('./Drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at ./Drive

# %%
# update custom packages
if not os.path.exists('/content/dsfinal'):
    # !git clone https://github.com/luk1684tw/dsfinal.git
# %cd /content/dsfinal
# !git pull
os.getcwd()
# Out:
# Cloning into 'dsfinal'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 3797 (delta 16), reused 20 (delta 10), pack-reused 3769
# Receiving objects: 100% (3797/3797), 7.29 MiB | 18.12 MiB/s, done.
# Resolving deltas: 100% (1319/1319), done.
# /content/dsfinal
# Already up to date.
# '/content/dsfinal'

# %%
# %cd l1-norm-pruning/
# !python main_E.py --scratch prunedA75.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist A75
# !python main_E.py --scratch prunedB75.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist B75
# !python main_E.py --scratch prunedC75.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist C75
# Out:
# /content/dsfinal/l1-norm-pruning
# [INFO] Start creating datasets
# [INFO] Distribution number is 75
# [INFO] Label distribution ratio: [1, 1, 1, 1, 1, 1, 1, 1, 1, 75]
# Files already downloaded and verified
# Files already downloaded and verified
# [INFO] Creating sampler
# [INFO] Creating dataloader
# [INFO] Return dataloaders
# [INFO] Loading model from /content/Drive/My Drive/Colab Notebooks/models/pruned/prunedA75.pth.tar
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=405 error=11 : invalid argument
# Train Epoch: 0 [0/50000 (0.0%)]	Loss: 2.335198
# Train Epoch: 0 [6400/50000 (12.8%)]	Loss: 0.448222
# Train Epoch: 0 [12800/50000 (25.6%)]	Loss: 0.572261
# Train Epoch: 0 [19200/50000 (38.4%)]	Loss: 0.436173
# Train Epoch: 0 [25600/50000 (51.2%)]	Loss: 0.592589
# Train Epoch: 0 [32000/50000 (63.9%)]	Loss: 0.823821
# Train Epoch: 0 [38400/50000 (76.7%)]	Loss: 0.482025
# Train Epoch: 0 [44800/50000 (89.5%)]	Loss: 0.424052
# ...

# %%
# %cd l1-norm-pruning/
# !python main_E.py --scratch prunedA100.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist A100
# !python main_E.py --scratch prunedB100.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist B100
# !python main_E.py --scratch prunedC100.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist C100
# Out:
# [Errno 2] No such file or directory: 'l1-norm-pruning/'
# /content/dsfinal/l1-norm-pruning
# [INFO] Start creating datasets
# [INFO] Distribution number is 100
# [INFO] Label distribution ratio: [100, 1, 1, 1, 1, 1, 1, 1, 1, 1]
# Files already downloaded and verified
# Files already downloaded and verified
# [INFO] Creating sampler
# [INFO] Creating dataloader
# [INFO] Return dataloaders
# [INFO] Loading model from /content/Drive/My Drive/Colab Notebooks/models/pruned/prunedA100.pth.tar
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=405 error=11 : invalid argument
# Train Epoch: 0 [0/50000 (0.0%)]	Loss: 2.346339
# Train Epoch: 0 [6400/50000 (12.8%)]	Loss: 0.427928
# Train Epoch: 0 [12800/50000 (25.6%)]	Loss: 0.287026
# Train Epoch: 0 [19200/50000 (38.4%)]	Loss: 0.280463
# Train Epoch: 0 [25600/50000 (51.2%)]	Loss: 0.471634
# Train Epoch: 0 [32000/50000 (63.9%)]	Loss: 0.439037
# Train Epoch: 0 [38400/50000 (76.7%)]	Loss: 0.409817
# ...

# %%
# %cd l1-norm-pruning/
# !python main_E.py --scratch prunedA200.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist A200
# !python main_E.py --scratch prunedB200.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist B200
# !python main_E.py --scratch prunedC200.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist C200

# %%
# %cd l1-norm-pruning/
# !python main_E.py --scratch prunedA500.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist A500
# !python main_E.py --scratch prunedB500.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist B500
# !python main_E.py --scratch prunedC500.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist C500

# %%
# %cd l1-norm-pruning/
# !python main_E.py --scratch prunedA500.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist A500
# !python main_E.py --scratch prunedB500.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist B500
# !python main_E.py --scratch prunedC500.pth.tar --dataset cifar10 --arch vgg --depth 16 --dist C500
# Out:
# /content/dsfinal/l1-norm-pruning
# [INFO] Start creating datasets
# [INFO] Distribution number is 500
# [INFO] Label distribution ratio: [1, 500, 1, 500, 1, 500, 1, 500, 1, 1]
# Files already downloaded and verified
# Files already downloaded and verified
# [INFO] Creating sampler
# [INFO] Creating dataloader
# [INFO] Return dataloaders
# [INFO] Loading model from /content/Drive/My Drive/Colab Notebooks/models/pruned/prunedB500.pth.tar
# Train Epoch: 0 [0/50000 (0.0%)]	Loss: 2.302872
# Train Epoch: 0 [6400/50000 (12.8%)]	Loss: 1.142209
# Train Epoch: 0 [12800/50000 (25.6%)]	Loss: 0.839062
# Train Epoch: 0 [19200/50000 (38.4%)]	Loss: 0.644922
# Train Epoch: 0 [25600/50000 (51.2%)]	Loss: 0.774831
# Train Epoch: 0 [32000/50000 (63.9%)]	Loss: 0.796691
# Train Epoch: 0 [38400/50000 (76.7%)]	Loss: 0.539653
# Train Epoch: 0 [44800/50000 (89.5%)]	Loss: 0.489745
# main_E.py:132: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# ...

# %%
# !python main_transfer.py --dataset cifar10 --scratch modelB500_best.pth.tar --method 1 --dist B500
# Out:
# [INFO] Method:  scratchB
# [INFO] Start creating datasets
# [INFO] Creating dataloader
# [INFO] Return dataloaders
# [INFO] Loading model from /content/Drive/My Drive/Colab Notebooks/models/scratchB/modelB500_best.pth.tar
# Old model features:  10
# [INFO] In Features 1024
# Get the new transfer learning model vgg(
#   (feature): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace)
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
# ...
